# %%
model_name= "resnet152"

f = open("./result/"+model_name+".txt", "r")
# print(f.read())

for line in f:
    line1 =(line.replace("\n","").split("train Loss: "))
    
    if len(line1) >= 2:
#         print(line)
        print(line1[1].split(" Acc: ")[1])
# Out:
# 0.0324
# 0.0833
# 0.2108
# 0.3333
# 0.4686
# 0.5912
# 0.6363
# 0.7324
# 0.7382
# 0.7696
# 0.8059
# 0.8029
# 0.8157
# 0.8186
# 0.8588
# 0.8304
# 0.8020
# 0.8176
# 0.8343
# 0.8451
# 0.8441
# 0.8549
# 0.8657
# 0.8549
# 0.8833
# 0.8980
# 0.8706
# 0.8578
# 0.8882
# 0.8686
# 0.9069
# 0.8765
# 0.8706
# 0.8902
# 0.8500
# 0.8608
# 0.8843
# 0.8843
# 0.8912
# 0.9039
# 0.9000
# 0.8931
# 0.8951
# 0.8775
# 0.8882
# 0.8892
# 0.8735
# 0.8716
# 0.8657
# 0.8824
# 0.8912
# 0.8931
# 0.9049
# 0.9039
# 0.9069
# 0.9088
# 0.9098
# 0.8794
# 0.9029
# 0.9137
# 0.9216
# 0.9147
# 0.9039
# 0.9039
# 0.9127
# 0.9010
# 0.9216
# 0.8912
# 0.8990
# 0.9088
# 0.9137
# 0.9284
# 0.9147
# 0.9284
# 0.9216
# 0.9324
# 0.9284
# 0.9196
# 0.9167
# 0.8941
# 0.9206
# 0.9049
# 0.8990
# 0.9088
# 0.9167
# 0.9069
# 0.9108
# 0.9049
# 0.9039
# 0.8922
# 0.9020
# 0.9059
# 0.9235
# 0.9392
# 0.9500
# 0.9471
# 0.9520
# 0.9216
# 0.9431
# 0.9451

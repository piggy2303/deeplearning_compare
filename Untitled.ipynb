# %%
model_name= "densenet201"

f = open("./result/"+model_name+".txt", "r")
# print(f.read())

for line in f:
    line1 =(line.replace("\n","").split("train Loss: "))
    
    if len(line1) >= 2:
#         print(line)
        print(line1[1].split(" Acc: ")[1])
# Out:
# 0.0725
# 0.1451
# 0.3529
# 0.5324
# 0.6647
# 0.7922
# 0.8569
# 0.9010
# 0.9196
# 0.9314
# 0.9353
# 0.9480
# 0.9392
# 0.9392
# 0.9304
# 0.9324
# 0.9412
# 0.9549
# 0.9324
# 0.9314
# 0.9402
# 0.9373
# 0.9431
# 0.9471
# 0.9471
# 0.9373
# 0.9275
# 0.9265
# 0.9284
# 0.9480
# 0.9500
# 0.9647
# 0.9647
# 0.9725
# 0.9559
# 0.9559
# 0.9520
# 0.9480
# 0.9373
# 0.9569
# 0.9304
# 0.9431
# 0.9529
# 0.9431
# 0.9696
# 0.9578
# 0.9686
# 0.9559
# 0.9804
# 0.9667
# 0.9392
# 0.9627
# 0.9510
# 0.9412
# 0.9667
# 0.9520
# 0.9676
# 0.9725
# 0.9725
# 0.9696
# 0.9706
# 0.9667
# 0.9696
# 0.9765
# 0.9559
# 0.9667
# 0.9471
# 0.9529
# 0.9686
# 0.9500
# 0.9451
# 0.9539
# 0.9706
# 0.9784
# 0.9647
# 0.9569
# 0.9608
# 0.9765
# 0.9843
# 0.9775
# 0.9755
# 0.9627
# 0.9735
# 0.9706
# 0.9676
# 0.9637
# 0.9775
# 0.9676
# 0.9686
# 0.9588
# 0.9588
# 0.9765
# 0.9706
# 0.9618
# 0.9716
# 0.9657
# 0.9824
# 0.9824
# 0.9745
# 0.9647
